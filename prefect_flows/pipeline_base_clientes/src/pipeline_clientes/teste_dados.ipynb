# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)

# %%
caminho = 'C:/Users/douglas.mendonca/OneDrive/Master/Relatorio_Controladoria/governanca_dw_controladoria/prefect_flows/pipeline_base_clientes/data/raw/clientes_imanager_2025-01-01.parquet'

# %%
dados = pd.read_parquet(caminho)

# %%
dados.head()
# Out:
#   data_posicao  id_regional_imanage regional              cidade  \
# 0   2025-01-01                    3  INATIVO            BAEPENDI
# 1   2025-01-01                    3  INATIVO            BAEPENDI
# 2   2025-01-01                    3  INATIVO  CACHOEIRA PAULISTA
# 3   2025-01-01                    3  INATIVO  CACHOEIRA PAULISTA
# 4   2025-01-01                    3  INATIVO             CAXAMBU
#
#   descricaosituacaocontrato tipo_documento  contratos     valor
# 0                 Cancelado           CNPJ          6    424.50
# 1                 Cancelado            CPF        236  16743.57
# 2                 Cancelado           CNPJ          1    105.42
# 3                 Cancelado            CPF         85   8172.31
# 4                 Cancelado           CNPJ         25   2770.34

# %%
caminho2 = 'C:/Users/douglas.mendonca/OneDrive/Master/Relatorio_Controladoria/governanca_dw_controladoria/prefect_flows/pipeline_base_clientes/data/staging/clientes_limpos_2025-01-01.parquet'

# %%
dados2 = pd.read_parquet(caminho2)

# %%
dados2.head()
# Out:
#          data  id_regional_imanager regional      cidade tipo_documento  \
# 0  2025-01-01                     4   ITAUNA   FLORESTAL           CNPJ
# 1  2025-01-01                     4   ITAUNA   FLORESTAL            CPF
# 2  2025-01-01                     4   ITAUNA  IGARATINGA           CNPJ
# 3  2025-01-01                     4   ITAUNA  IGARATINGA            CPF
# 4  2025-01-01                     4   ITAUNA      ITAUNA           CNPJ
#
#    aguardando_conexao  cancelado  conectado_ativo  \
# 0                   0          6                0
# 1                   1        596               24
# 2                   0          7                0
# 3                   0        466               37
# 4                  40        285              104
#
#    conectado_inadimplente_parcial  conectado_inadimplente_total  inadimplente  \
# 0                               0                             0             0
# ...

# %%
caminho3 = 'C:/Users/douglas.mendonca/OneDrive/Master/Relatorio_Controladoria/governanca_dw_controladoria/prefect_flows/pipeline_base_clientes/data/processed/fato_clientes_2025-01-01.parquet'

# %%
dados3 = pd.read_parquet(caminho3)

# %%
dados3.head()
# Out:
#    id_tempo  id_regional  id_cidade tipo_documento  qtde_contratos  \
# 0  20250101            5         47           CNPJ              45
# 1  20250101            5         47            CPF            5358
# 2  20250101            5         44           CNPJ             430
# 3  20250101            5         44            CPF           12288
# 4  20250101            5         43           CNPJ               7
#
#    aguardando_conexao  cancelado  conectado_ativo  \
# 0                   0         43                2
# 1                   2       5132              203
# 2                  40        285              104
# 3                   5      10543             1629
# 4                   0          7                0
#
#    conectado_inadimplente_parcial  conectado_inadimplente_total  inadimplente  \
# 0                               0                             0             0
# 1                               0                            16             0
# ...
