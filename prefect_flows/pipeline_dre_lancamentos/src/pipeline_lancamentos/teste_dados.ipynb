# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)

# %%
caminho = 'C:/Users/douglas.mendonca/OneDrive/Master/Relatorio_Controladoria/governanca_dw_controladoria/prefect_flows/pipeline_dre_lancamentos/data/processed/fato_dre_preparado.parquet'

# %%
dados = pd.read_parquet(caminho)

# %%
dados.head()
# Out:
#    id_tempo  id_item  id_natureza  id_detalhe  id_conta  id_regcid     valor
# 0  20250226        2           21           1        50        113 -536.9000
# 1  20250215        4           72          13        96        113   -3.6541
# 2  20250215        4           73          13        97        113   -4.9302
# 3  20250215        4           73          13        97        113   -6.0125
# 4  20250215        4           74          13        98        113   -7.3081
